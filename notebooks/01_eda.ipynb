# %% [markdown]
# # WeatherAUS EDA
#
# This notebook generates basic statistics and a set of exploratory plots (saved into `reports/figures/`).
#
# Run after placing `dataset/weatherAUS.csv` in your workspace.

# %%
import os, sys
sys.path.append(os.getcwd())

from src.eda import run_eda
run_eda()
