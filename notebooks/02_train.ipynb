# %% [markdown]
# # Train & Evaluate Models
#
# This notebook trains and compares multiple models for:
# - **Temperature regression** (predict `MaxTemp`)
# - **RainTomorrow classification** (predict `RainTomorrow`)
#
# After running, check `models/` for the best saved pipelines and `reports/` for metrics + plots.

# %%
import os, sys
sys.path.append(os.getcwd())

from src.train_evaluate import train_and_evaluate
train_and_evaluate()
